# %%
import matplotlib.pyplot as pl
from PIL import Image , ImageOps

# %%
import pandas as pd

# %%
import pandas as pd
import zipfile
import io

# Path to the zip file
zip_path = r"C:\Users\273309\Downloads\titanic.zip"

# Specify which file in the zip you want to read (e.g., 'train.csv')
with zipfile.ZipFile(zip_path) as z:
    # Read the specific CSV file from the zip
    with z.open('train.csv') as f:
        df_train = pd.read_csv(io.BytesIO(f.read()))
        
# Now df_train contains the data from train.csv

# %%
df_train.shape
# Out:
# (891, 12)

# %%
# Two Data Structures
# Data Frame
# Series

type(df_train)
# Out:
# pandas.core.frame.DataFrame

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_train.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df_train = df_train.loc[:, ~df_train.columns.str.lower().isin(['cabin'])]

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 76.7+ KB

# %%
# Printing Statistical Report

df_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# To check null values

df_train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64

# %%
# To check null values

df_train.isnull().sum () / df_train.shape[0] * 100
# Out:
# PassengerId     0.000000
# Survived        0.000000
# Pclass          0.000000
# Name            0.000000
# Sex             0.000000
# Age            19.865320
# SibSp           0.000000
# Parch           0.000000
# Ticket          0.000000
# Fare            0.000000
# Embarked        0.224467
# dtype: float64

# %%
# Data Analysis
# You need to mention these null values in your report

# Machine learning
# Fill these values

# How to fill?
# Ffill
# Bfill
# Mean/Median/Mode

# %%
df_train["Age"].mean()
# Out:
# 29.69911764705882

# %%
df_train["Age"] = df_train["Age"].fillna(df_train["Age"].mean())

# %%
df_train.isnull().sum () / df_train.shape[0] * 100
# Out:
# PassengerId    0.000000
# Survived       0.000000
# Pclass         0.000000
# Name           0.000000
# Sex            0.000000
# Age            0.000000
# SibSp          0.000000
# Parch          0.000000
# Ticket         0.000000
# Fare           0.000000
# Embarked       0.224467
# dtype: float64

# %%
df_train["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df_train["Embarked"].value_counts()
# Out:
# Embarked
# S    644
# C    168
# Q     77
# Name: count, dtype: int64

# %%
df_train["Embarked"] = df_train["Embarked"].fillna("S")

# %%
df_train.isnull().sum () / df_train.shape[0] * 100
# Out:
# PassengerId    0.0
# Survived       0.0
# Pclass         0.0
# Name           0.0
# Sex            0.0
# Age            0.0
# SibSp          0.0
# Parch          0.0
# Ticket         0.0
# Fare           0.0
# Embarked       0.0
# dtype: float64

# %%
df_train[df_train['Survived'] == 0]['Sex'].value_counts()
# Out:
# Sex
# male      468
# female     81
# Name: count, dtype: int64

# %%
df_train[(df_train['Survived'] == 0) & (df_train['Age'] < 18)]['Sex'].value_counts()
# Out:
# Sex
# male      35
# female    17
# Name: count, dtype: int64

# %%
# Groupby

df_train.groupby(['Survived','Sex'])[['Fare','Age']].mean()
# Out:
#                       Fare        Age
# Survived Sex
# 0        female  23.024385  26.023272
#          male    21.960993  31.175224
# 1        female  51.938573  28.979263
#          male    40.821484  27.631705

# %%
df_train.groupby(['Survived'])[['Sex']].count()
# Out:
#           Sex
# Survived
# 0         549
# 1         342

# %%
# Feature Engineering

df_train['is_adult']= None

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked is_adult
# 0      0         A/5 21171   7.2500        S     None
# 1      0          PC 17599  71.2833        C     None
# 2      0  STON/O2. 3101282   7.9250        S     None
# 3      0            113803  53.1000        S     None
# ...

# %%
import numpy as np

df_train['is_adult'] = np.where(df_train['Age'] > 18, 1, 0)

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked  is_adult
# 0      0         A/5 21171   7.2500        S         1
# 1      0          PC 17599  71.2833        C         1
# 2      0  STON/O2. 3101282   7.9250        S         1
# 3      0            113803  53.1000        S         1
# ...

# %%
df_train['Fare'].quantile(0.25)
# Out:
# 7.9104

# %%
df_train['Fare'].quantile(0.50)
# Out:
# 14.4542

# %%
df_train['Fare'].quantile(0.75)
# Out:
# 31.0

# %%
df_train['Fare'].quantile(0.100)
# Out:
# 7.55

# %%
df_train["Fare_bin"] = np.where(df_train['Fare'] < 7.9, "low",
                               np.where((df_train['Fare'] > 7.9) & (df_train['Fare'] < 14.45), "Medium",
                                       np.where(df_train['Fare'] > 14.45, "High", None)))

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked  is_adult Fare_bin
# 0      0         A/5 21171   7.2500        S         1      low
# 1      0          PC 17599  71.2833        C         1     High
# 2      0  STON/O2. 3101282   7.9250        S         1   Medium
# ...

# %%
# outliers
# 1.) Boxplot
# 2.) scatterplot

# Box and whisker plot

import matplotlib.pyplot as plt
import seaborn as sns

sns.boxplot(x = df_train['Age'])
# Out:
# <Axes: xlabel='Age'>

# %%
sns.boxplot(x = df_train['Fare'])
# Out:
# <Axes: xlabel='Fare'>

# %%
# Scatterplot
sns.scatterplot(x = df_train['Fare'] , y = df_train['Age'] , hue= df_train['Survived'])
# Out:
# <Axes: xlabel='Fare', ylabel='Age'>

# %%
# How to treat outliers
# Caping
# Remove

# %%
df_test = df_train.copy()

# %%
df_test.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked  is_adult Fare_bin
# 0      0         A/5 21171   7.2500        S         1      low
# 1      0          PC 17599  71.2833        C         1     High
# 2      0  STON/O2. 3101282   7.9250        S         1   Medium
# ...

# %%
df_train[df_train['Fare'] > 170]['Fare']
# Out:
# 27     263.0000
# 88     263.0000
# 118    247.5208
# 258    512.3292
# 299    247.5208
# 311    262.3750
# 341    263.0000
# 377    211.5000
# 380    227.5250
# 438    263.0000
# 527    221.7792
# 557    227.5250
# 679    512.3292
# 689    211.3375
# 700    227.5250
# 716    227.5250
# 730    211.3375
# 737    512.3292
# 742    262.3750
# 779    211.3375
# Name: Fare, dtype: float64

# %%
len(df_train[df_train['Fare'] > 170]['Fare'])
# Out:
# 20

# %%
df_train[df_train['Fare'] > 200]['Fare']
# Out:
# 27     263.0000
# 88     263.0000
# 118    247.5208
# 258    512.3292
# 299    247.5208
# 311    262.3750
# 341    263.0000
# 377    211.5000
# 380    227.5250
# 438    263.0000
# 527    221.7792
# 557    227.5250
# 679    512.3292
# 689    211.3375
# 700    227.5250
# 716    227.5250
# 730    211.3375
# 737    512.3292
# 742    262.3750
# 779    211.3375
# Name: Fare, dtype: float64

# %%
df_train[df_train['Fare'] < 200]['Fare'].max()
# Out:
# 164.8667

# %%
#df_train[df_train['Fare'] < 200]['Fare'].max()

# %%
df_train.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# is_adult       0
# Fare_bin       0
# dtype: int64

# %%
#To drop all null values
#df_train.dropna(inplace=True)

# %%
df_test.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked  is_adult Fare_bin
# 0      0         A/5 21171   7.2500        S         1      low
# 1      0          PC 17599  71.2833        C         1     High
# 2      0  STON/O2. 3101282   7.9250        S         1   Medium
# ...

# %%
# Encoding 
# Label Encoding
# One Hot Encoding

pd.get_dummies(df_train['Fare_bin'],drop_first = True,dtype=int)
# Out:
#      Medium  low
# 0         0    1
# 1         0    0
# 2         1    0
# 3         0    0
# 4         1    0
# ..      ...  ...
# 886       1    0
# 887       0    0
# 888       0    0
# 889       0    0
# 890       0    1
#
# [891 rows x 2 columns]

# %%
# Label Encoding
df_test["Sex"]
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object

# %%
# Label Encoding
mapping_dict = {
    "male": 0,  # Fixed: Added closing quotation mark and changed : to proper syntax
    "female": 1  # Fixed: Changed : to proper syntax
}

df_test["Sex"] = df_test["Sex"].map(mapping_dict)

# %%
df_test.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare Embarked  is_adult Fare_bin
# 0         A/5 21171   7.2500        S         1      low
# 1          PC 17599  71.2833        C         1     High
# 2  STON/O2. 3101282   7.9250        S         1   Medium
# 3            113803  53.1000        S         1     High
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()  # Create an instance of LabelEncoder with proper capitalization

df_test['Embarked'] = le.fit_transform(df_test['Embarked'])

# %%
df_test.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0      1      0
# 2                             Heikkinen, Miss. Laina    1  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0      1      0
# 4                           Allen, Mr. William Henry    0  35.0      0      0
#
#              Ticket     Fare  Embarked  is_adult Fare_bin
# 0         A/5 21171   7.2500         2         1      low
# 1          PC 17599  71.2833         0         1     High
# 2  STON/O2. 3101282   7.9250         2         1   Medium
# 3            113803  53.1000         2         1     High
# ...

# %%
#countplot

# The correct function is sns.countplot(), not sns.count()
# Make sure seaborn is imported as sns
import seaborn as sns

# Use countplot to visualize the count of observations by Sex
sns.countplot(x='Sex', data=df_train)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x= df_train['Sex'],color = "red")
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
# Countplot

sns.countplot(x = df_train['Sex'], hue = df_train['Sex'])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
#Historgram

sns.histplot(df_train['Age'],bins='auto',kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
#Historgram
plt.figure(figsize = (8,6))

sns.histplot(df_train['Age'],bins='auto',kde=True,color="red")
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.boxplot( x = df_train['Survived'] , y =df_train['Age'])
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
sns.boxplot( x = df_train['Sex'] , y =df_train['Fare'])
# Out:
# <Axes: xlabel='Sex', ylabel='Fare'>

# %%
# Select only numeric columns for correlation
numeric_columns = df_test.select_dtypes(include=['int64', 'float64'])

# Calculate correlation on numeric columns only
numeric_columns.corr()

# Alternatively, if you want to see which columns are causing the issue:
# print("Numeric columns:", df_test.select_dtypes(include=['int64', 'float64']).columns.tolist())
# print("Non-numeric columns:", df_test.select_dtypes(exclude=['int64', 'float64']).columns.tolist())
# Out:
#              PassengerId  Survived    Pclass       Sex       Age     SibSp  \
# PassengerId     1.000000 -0.005007 -0.035144 -0.042939  0.033207 -0.057527
# Survived       -0.005007  1.000000 -0.338481  0.543351 -0.069809 -0.035322
# Pclass         -0.035144 -0.338481  1.000000 -0.131900 -0.331339  0.083081
# Sex            -0.042939  0.543351 -0.131900  1.000000 -0.084153  0.114631
# Age             0.033207 -0.069809 -0.331339 -0.084153  1.000000 -0.232625
# SibSp          -0.057527 -0.035322  0.083081  0.114631 -0.232625  1.000000
# Parch          -0.001652  0.081629  0.018443  0.245489 -0.179191  0.414838
# Fare            0.012658  0.257307 -0.549500  0.182333  0.091566  0.159651
#
#                 Parch      Fare
# PassengerId -0.001652  0.012658
# Survived     0.081629  0.257307
# Pclass       0.018443 -0.549500
# Sex          0.245489  0.182333
# Age         -0.179191  0.091566
# SibSp        0.414838  0.159651
# Parch        1.000000  0.216225
# ...

# %%
plt.figure(figsize = (10,10))


numeric_df = df_test.select_dtypes(include=['float64', 'int64'])

sns.heatmap(numeric_df.corr(), annot=True)

print("Columns used in correlation:", numeric_df.columns.tolist())
# Out:
# Columns used in correlation: ['PassengerId', 'Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
df_test
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex        Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    0  22.000000      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.000000      1
# 2                               Heikkinen, Miss. Laina    1  26.000000      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.000000      1
# 4                             Allen, Mr. William Henry    0  35.000000      0
# ...

# %%
sns.violinplot( x = df_train['Sex'] , y = df_train['Fare'])
# Out:
# <Axes: xlabel='Sex', ylabel='Fare'>

# %%
sns.pairplot(df_test)

# %%
df_test.head()

# %%
# Thanks project Train code 
# Training
